# %%
import pandas as pd

# %%
data = pd.read_csv('../Data/cleanedData/cleaned_data_project.csv')

# %%
s = data.groupby('Chủ đầu tư')['Mức giá'].mean()

# %%
top_20 = s.sort_values(ascending=False).head(20)

top_20.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
